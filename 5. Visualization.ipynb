# %%
# Matplot lib and Seaborn - Old 
# ddgs and plot lib -New

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
pd.DataFrame(randn(1000))
# Out:
#             0
# 0    0.125785
# 1    0.077200
# 2    0.984141
# 3    0.455582
# 4   -1.144108
# ..        ...
# 995 -0.041373
# 996  1.913163
# 997  0.565678
# 998  0.700215
# 999  1.417256
#
# [1000 rows x 1 columns]

# %%
df=pd.DataFrame(randn(1000), index= pd.date_range('2019-06-07', periods= 1000), columns= ['value'])
ts=pd.Series(randn(1000), index=pd.date_range('2019-06-07', periods=1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.133985
# 2019-06-08 -0.954940
# 2019-06-09  0.208235
# 2019-06-10 -0.083357
# 2019-06-11  0.722755

# %%
df['value']= df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.133985
# 2019-06-08 -1.088925
# 2019-06-09 -0.880690
# 2019-06-10 -0.964047
# 2019-06-11 -0.241292

# %%
ts
# Out:
# 2019-06-07    0.401289
# 2019-06-08    0.099955
# 2019-06-09    0.719468
# 2019-06-10    0.588070
# 2019-06-11    1.159937
#                 ...
# 2022-02-26   -1.225450
# 2022-02-27   -0.834175
# 2022-02-28    0.492579
# 2022-03-01    1.068797
# 2022-03-02    1.716106
# Freq: D, Length: 1000, dtype: float64

# %%
# cumsum - 
# cumulative sum means = first items - second items is sum of 1 and 2 item
ts=ts.cumsum()  
ts.head()
# Out:
# 2019-06-07    0.401289
# 2019-06-08    0.501244
# 2019-06-09    1.220712
# 2019-06-10    1.808782
# 2019-06-11    2.968719
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot()
# In X axis = index, Y axis = data values
# Out:
# <AxesSubplot:>

# %%
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
# data set example
iris= sns.load_dataset('iris')
print(iris.head())
print(type(iris))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>

# %%
ax= iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
ts.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# removing catergorical data species- for neat visualization
df=iris.drop(['species'], axis=1) 
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot(kind ='barh')
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.188831 -0.602460 -0.273065  0.097582
# 1 -0.123628 -0.457982  0.006524 -1.383576
# 2  0.039883 -2.361869 -2.008347  0.893201
# 3  0.833859 -1.506869 -0.601660 -0.052408
# 4  1.146574  0.629286 -1.369907 -0.740776
# 5 -0.102122  0.462636  2.252362 -0.409820
# 6  0.056570 -0.943007  1.613559  0.133606
# 7  2.050249  0.945191  0.793765 -0.264657
# 8  0.085861  1.239001 -0.474855  0.629181
# 9  2.114237 -0.777967 -0.458055  0.220135

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# horizontal bars-barh
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
# histogram - no. of occurence of a plant part - sepal, petal 
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# stack - means plot in which one items is above another item
# bin means - graph size can be changed using this - compare the difference of X & Y axis-(8,30) below fig (8,40)
iris.plot(kind='hist', stacked= False, bins= 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# this graph shows orange is less than green
# blue is less than green
iris.plot(kind='hist', stacked= True, bins= 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# orientation - horizontal
iris.plot(kind='hist', stacked= True, bins= 50, orientation= 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
# orientation - horizontal
iris.plot(kind='hist', stacked= True, orientation= 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
# Diff() - Calculates difference of a Dataframe element with another 
# element in the Dataframe
iris['sepal_width'].diff().plot(kind='hist', stacked= True, bins =50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=iris.drop(['species'], axis=1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
# color - color, alpha - intensity of color
df.diff().hist(color= 'b', alpha=0.4, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.plot.scatter(x='sepal_length', y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length', y='petal_length', c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# bubble size - s=190
df.plot.scatter(x='sepal_length', y='petal_length', c='sepal_width', s=190)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length', y='petal_length',gridsize=50, C='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
d=df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d=df.head(3).T
print(df.head(3))
print("\n\n", d)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
#
#
#                  0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots= True, figsize=(20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
# autopct- show percentages- till 2 decimal point - 0.2 f
d.plot.pie(subplots= True, figsize=(20,20), fontsize=18, autopct= '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
# kde= kernal density estimation
# important for data analysis
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(8,8), diagonal= 'kde', color='violet')
plt.show()

# %%
# individual kde= kernal density estimation graph
df['sepal_length'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['petal_width'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#  
ts.plot(style='r--', label='Series', legend=True )
# Out:
# <AxesSubplot:>

# %%
#  
ts.plot(style='r*', label='Series', legend=True )
# Out:
# <AxesSubplot:>

# %%
# logy = means log or sym scaling 
df.plot(legend=True, figsize=(10,5), logy= True)
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots =True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
# sharex means not sharing along x axis. sharing along Y axis is fine. 
df.plot(subplots =True, sharex =False, layout= (2,3), figsize=(16,8))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# Class practice questions 
# From Titanic dataset

# %%
df=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv')
df # user sep="\t" if required
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# show survived in histogram
df['Survived'].plot(kind='hist', title= "Plot for Passangers Survived")
# Out:
# <AxesSubplot:title={'center':'Plot for Passangers Survived'}, ylabel='Frequency'>

# %%
# Plot a graph for fare price variation
df['Fare'].diff().plot(kind='hist', figsize=(10, 5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Plot a graph for fare price variation
df['Fare'].plot(figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
# Plot a graph for fare price variation
df['Fare'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Fare'].plot(kind='barh', figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plotly & cufflinks

# %% [markdown]
# Plotly enables us to create beautiful interactive web-based visualizations plots that can use in dashboards or websites (you can save them as html file ot static images).

# %% [markdown]
# We can call plots directly off of a pandas data frame.

# %%
! pip install plotly 
! pip install cufflinks
! pip install folium

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

# %%
import cufflinks as cf

# %% [markdown]
# # Using Cufflinks and iplot()
# 1. line
# 2. scatter
# 3. bar
# 4. box
# 5. spread
# 6. ratio
# 7. heatmap
# 8. surface
# 9. histogram
# 10. bubble
